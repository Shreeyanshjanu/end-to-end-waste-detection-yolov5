# %%
import gdown

# %%
url="https://drive.google.com/file/d/1XceQhWcPiMRdITwf6o6QNcFGmvIsTTOk/view?usp=sharing"

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1XceQhWcPiMRdITwf6o6QNcFGmvIsTTOk'

# %%
prefix='https://drive.google.com/uc?/export=download&id='

# %%
import os
os.chdir("../")

# %%
gdown.download(prefix+file_id,"data/waste_data.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1XceQhWcPiMRdITwf6o6QNcFGmvIsTTOk
# To: c:\Users\arthu\Desktop\MLProjects\end-to-end-waste-detection-yolov5\data\waste_data.zip
# 100%|██████████| 2.55M/2.55M [00:00<00:00, 4.35MB/s]
# 'data/waste_data.zip'

# %%
pwd
# Out:
# 'c:\\Users\\arthu\\Desktop\\MLProjects\\end-to-end-waste-detection-yolov5\\research'
